# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("Train_details_22122017.csv")
# Out:
# /Users/siva/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head()
# Out:
#   Train No    Train Name SEQ Station Code  Station Name Arrival time  \
# 0      107  SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 1      107  SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 2      107  SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 3      107  SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 4      108  VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
#
#   Departure Time Distance Source Station Source Station Name  \
# 0       10:25:00        0            SWV     SAWANTWADI ROAD
# 1       11:08:00       32            SWV     SAWANTWADI ROAD
# 2       11:30:00       49            SWV     SAWANTWADI ROAD
# 3       00:00:00       78            SWV     SAWANTWADI ROAD
# 4       20:30:00        0            MAO         MADGOAN JN.
#
#   Destination Station Destination Station Name
# 0                 MAO              MADGOAN JN.
# 1                 MAO              MADGOAN JN.
# 2                 MAO              MADGOAN JN.
# 3                 MAO              MADGOAN JN.
# 4                 SWV          SAWANTWADI ROAD

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186124 entries, 0 to 186123
# Data columns (total 12 columns):
# Train No                    186124 non-null category
# Train Name                  186124 non-null category
# SEQ                         186124 non-null object
# Station Code                186124 non-null object
# Station Name                186124 non-null object
# Arrival time                186119 non-null object
# Departure Time              186119 non-null object
# Distance                    186119 non-null object
# Source Station              186114 non-null category
# Source Station Name         186114 non-null category
# Destination Station         186114 non-null object
# Destination Station Name    186114 non-null category
# dtypes: category(5), object(7)
# memory usage: 12.6+ MB

# %%
train["Destination Station Name"] = train["Destination Station Name"].astype("category")

# %%
src_station = train.groupby(by = "Source Station")

# %%
src_station.head()
# Out:
#        Train No    Train Name SEQ Station Code  Station Name Arrival time  \
# 0           107  SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 1           107  SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 2           107  SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 3           107  SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 4           108  VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# 5           108  VLNK-MAO-SWV   2         KRMI       KARMALI     21:04:00
# 6           108  VLNK-MAO-SWV   3         THVM        THIVIM     21:26:00
# 7           108  VLNK-MAO-SWV   4          SWV  SAWANTWADI R     22:25:00
# 8           128  MAO-KOP SPEC   1          MAO   MADGOAN JN.     19:40:00
# 30          290  PALACE ON WH   1          DSJ  DELHI-SAFDAR     18:30:00
# 31          290  PALACE ON WH   2         GADJ   GANDHINAGAR     03:45:00
# 32          290  PALACE ON WH   3           JP    JAIPUR JN.     08:00:00
# 33          290  PALACE ON WH   4          DPA     DURGAPURA     18:00:00
# 34          290  PALACE ON WH   5          SWM  SAWAI MADHOP     04:45:00
# 44          401  BSB BHARATDA   1          AWB    AURANGABAD     21:30:00
# 45          401  BSB BHARATDA   2          MMR    MANMAD JN.     01:20:00
# 46          401  BSB BHARATDA   3          BSL  BHUSAVAL JN.     05:20:00
# 47          401  BSB BHARATDA   4          KNW   KHANDWA JN.     07:30:00
# 48          401  BSB BHARATDA   5          JHS     JHANSI JN     14:55:00
# 56          421  LKO-SVDK FTR   1          LKO   LUCKNOW JN.     23:00:00
# 57          421  LKO-SVDK FTR   2          FGR     FATEHGARH     03:03:00
# 58          421  LKO-SVDK FTR   3          KSJ   KASGANJ JN.     06:00:00
# 59          421  LKO-SVDK FTR   4           BE  BAREILLY JN.     09:42:00
# 60          421  LKO-SVDK FTR   5         SVDK  SHRI MATA VA     08:00:00
# 61          422  SVDK-LKO FTR   1         SVDK  SHRI MATA VA     11:45:00
# 62          422  SVDK-LKO FTR   2           BE  BAREILLY JN.     03:25:00
# 63          422  SVDK-LKO FTR   3          KSJ   KASGANJ JN.     06:35:00
# 64          422  SVDK-LKO FTR   4          FGR     FATEHGARH     09:30:00
# 65          422  SVDK-LKO FTR   5          LKO   LUCKNOW JN.     14:30:00
# 66          477  FTR TRAIN NO   1          SSA         SIRSA     12:10:00
# ...         ...           ...  ..          ...           ...          ...
# 184278    98302           BR4   1         BEPR  BELAPUR C.B.     00:00:00
# 184279    98302           BR4   2         CSMT    CST-MUMBAI     05:08:00
# 184282    98304           BR6   1         BEPR  BELAPUR C.B.     00:00:00
# 184452    98500            V2   1          VSH         VASHI     00:00:00
# 184606    98600            M2   1         MNKD      MANKHURD     00:00:00
# 184607    98600            M2   2         CSMT    CST-MUMBAI     08:41:00
# 184610    98602            M4   1         MNKD      MANKHURD     00:00:00
# 184611    98602            M4   2         CSMT    CST-MUMBAI     09:33:00
# 184614    98604           CM2   1         CMBR       CHEMBUR     00:00:00
# 184615    98604           CM2   2         CSMT    CST-MUMBAI     09:45:00
# 185104    99200          TNU2   1          NEU         NERUL     00:00:00
# 185105    99200          TNU2   2          TNA         THANE     06:52:00
# 185108    99202          TNU4   1          NEU         NERUL     00:00:00
# 185109    99202          TNU4   2          TNA         THANE     07:25:00
# 185112    99204          TNU6   1          NEU         NERUL     00:00:00
# 185424    99801  LNL-PUNE EMU   1          LNL       LONAVLA     05:20:00
# 185425    99801  LNL-PUNE EMU   2          MVL       MALAVLI     05:27:00
# 185426    99801  LNL-PUNE EMU   3         KMST       KAMSHET     05:34:00
# 185427    99801  LNL-PUNE EMU   4         KNHE         KANHE     05:37:00
# 185428    99801  LNL-PUNE EMU   5          VDN       VADGAON     05:41:00
# 185645    99814  PUNE-LNL EMU   1         SVJR  SHIVAJINAGAR     11:20:00
# 185646    99814  PUNE-LNL EMU   2           KK        KHADKI     11:23:00
# 185647    99814  PUNE-LNL EMU   3         DAPD        DAPODI     11:28:00
# 185648    99814  PUNE-LNL EMU   4         KSWD     KASARWADI     11:32:00
# 185649    99814  PUNE-LNL EMU   5          PMP        PIMPRI     11:35:00
# 186029    99901  TGN-PUNE EMU   1          TGN      TALEGAON     00:05:00
# 186030    99901  TGN-PUNE EMU   2         GRWD     GHORAWADI     00:08:00
# 186031    99901  TGN-PUNE EMU   3         BGWI     BEGDAEWAI     00:11:00
# 186032    99901  TGN-PUNE EMU   4         DEHR     DEHU ROAD     00:15:00
# 186033    99901  TGN-PUNE EMU   5         AKRD        AKURDI     00:20:00
#
#        Departure Time Distance Source Station           Source Station Name  \
# 0            10:25:00        0            SWV               SAWANTWADI ROAD
# 1            11:08:00       32            SWV               SAWANTWADI ROAD
# 2            11:30:00       49            SWV               SAWANTWADI ROAD
# 3            00:00:00       78            SWV               SAWANTWADI ROAD
# 4            20:30:00        0            MAO                   MADGOAN JN.
# 5            21:06:00       33            MAO                   MADGOAN JN.
# 6            21:28:00       51            MAO                   MADGOAN JN.
# 7            00:00:00       83            MAO                   MADGOAN JN.
# 8            19:40:00        0            MAO                   MADGOAN JN.
# 30           18:30:00        0            DSJ             DELHI-SAFDAR JANG
# 31           07:45:00      306            DSJ             DELHI-SAFDAR JANG
# 32           11:55:00      311            DSJ             DELHI-SAFDAR JANG
# 33           20:00:00      318            DSJ             DELHI-SAFDAR JANG
# 34           08:40:00      442            DSJ             DELHI-SAFDAR JANG
# 44           21:30:00        0            AWB                    AURANGABAD
# 45           01:30:00      131            AWB                    AURANGABAD
# 46           05:30:00      315            AWB                    AURANGABAD
# 47           07:35:00      438            AWB                    AURANGABAD
# 48           15:05:00     1003            AWB                    AURANGABAD
# 56           23:00:00        0            LKO                   LUCKNOW JN.
# 57           03:30:00      207            LKO                   LUCKNOW JN.
# 58           06:30:00      319            LKO                   LUCKNOW JN.
# 59           09:47:00      456            LKO                   LUCKNOW JN.
# 60           08:00:00     1276            LKO                   LUCKNOW JN.
# 61           11:45:00        0           SVDK  SHRI MATA VAISHNO DEVI KATRA
# 62           03:30:00      820           SVDK  SHRI MATA VAISHNO DEVI KATRA
# 63           07:05:00      956           SVDK  SHRI MATA VAISHNO DEVI KATRA
# 64           09:35:00     1069           SVDK  SHRI MATA VAISHNO DEVI KATRA
# 65           14:30:00     1277           SVDK  SHRI MATA VAISHNO DEVI KATRA
# 66           12:10:00        0            SSA                         SIRSA
# ...               ...      ...            ...                           ...
# 184278       04:04:00        0           BEPR                 BELAPUR C.B.D
# 184279       00:00:00       38           BEPR                 BELAPUR C.B.D
# 184282       04:28:00        0           BEPR                 BELAPUR C.B.D
# 184452       04:00:00        0            VSH                         VASHI
# 184606       08:00:00        0           MNKD                      MANKHURD
# 184607       00:00:00       21           MNKD                      MANKHURD
# 184610       08:52:00        0           MNKD                      MANKHURD
# 184611       00:00:00       21           MNKD                      MANKHURD
# 184614       09:09:00        0           CMBR                       CHEMBUR
# 184615       00:00:00       17           CMBR                       CHEMBUR
# 185104       06:20:00        0            NEU                         NERUL
# 185105       00:00:00       20            NEU                         NERUL
# 185108       06:53:00        0            NEU                         NERUL
# 185109       00:00:00       20            NEU                         NERUL
# 185112       07:30:00        0            NEU                         NERUL
# 185424       05:20:00        0            LNL                       LONAVLA
# 185425       05:28:00        7            LNL                       LONAVLA
# 185426       05:35:00       15            LNL                       LONAVLA
# 185427       05:38:00       20            LNL                       LONAVLA
# 185428       05:42:00       25            LNL                       LONAVLA
# 185645       11:20:00        0           SVJR                  SHIVAJINAGAR
# 185646       11:24:00        3           SVJR                  SHIVAJINAGAR
# 185647       11:29:00        5           SVJR                  SHIVAJINAGAR
# 185648       11:33:00        9           SVJR                  SHIVAJINAGAR
# 185649       11:36:00       11           SVJR                  SHIVAJINAGAR
# 186029       00:05:00        0            TGN                      TALEGAON
# 186030       00:09:00        3            TGN                      TALEGAON
# 186031       00:12:00        6            TGN                      TALEGAON
# 186032       00:16:00        9            TGN                      TALEGAON
# 186033       00:21:00       14            TGN                      TALEGAON
#
#        Destination Station            Destination Station Name
# 0                      MAO                         MADGOAN JN.
# 1                      MAO                         MADGOAN JN.
# 2                      MAO                         MADGOAN JN.
# 3                      MAO                         MADGOAN JN.
# 4                      SWV                     SAWANTWADI ROAD
# 5                      SWV                     SAWANTWADI ROAD
# 6                      SWV                     SAWANTWADI ROAD
# 7                      SWV                     SAWANTWADI ROAD
# 8                      KOP  CHHATRAPATI SHAHU MAHARAJ TERMINUS
# 30                     DSJ                   DELHI-SAFDAR JANG
# 31                     DSJ                   DELHI-SAFDAR JANG
# 32                     DSJ                   DELHI-SAFDAR JANG
# 33                     DSJ                   DELHI-SAFDAR JANG
# 34                     DSJ                   DELHI-SAFDAR JANG
# 44                     BSB                        VARANASI JN.
# 45                     BSB                        VARANASI JN.
# 46                     BSB                        VARANASI JN.
# 47                     BSB                        VARANASI JN.
# 48                     BSB                        VARANASI JN.
# 56                    SVDK        SHRI MATA VAISHNO DEVI KATRA
# 57                    SVDK        SHRI MATA VAISHNO DEVI KATRA
# 58                    SVDK        SHRI MATA VAISHNO DEVI KATRA
# 59                    SVDK        SHRI MATA VAISHNO DEVI KATRA
# 60                    SVDK        SHRI MATA VAISHNO DEVI KATRA
# 61                     LKO                         LUCKNOW JN.
# 62                     LKO                         LUCKNOW JN.
# 63                     LKO                         LUCKNOW JN.
# 64                     LKO                         LUCKNOW JN.
# 65                     LKO                         LUCKNOW JN.
# 66                     SSA                               SIRSA
# ...                    ...                                 ...
# 184278                CSTM                          CST-MUMBAI
# 184279                CSTM                          CST-MUMBAI
# 184282                CSTM                          CST-MUMBAI
# 184452                CSTM                          CST-MUMBAI
# 184606                CSTM                          CST-MUMBAI
# 184607                CSTM                          CST-MUMBAI
# 184610                CSTM                          CST-MUMBAI
# 184611                CSTM                          CST-MUMBAI
# 184614                CSTM                          CST-MUMBAI
# 184615                CSTM                          CST-MUMBAI
# 185104                 TNA                               THANE
# 185105                 TNA                               THANE
# 185108                 TNA                               THANE
# 185109                 TNA                               THANE
# 185112                 TNA                               THANE
# 185424                PUNE                            PUNE JN.
# 185425                PUNE                            PUNE JN.
# 185426                PUNE                            PUNE JN.
# 185427                PUNE                            PUNE JN.
# 185428                PUNE                            PUNE JN.
# 185645                 LNL                             LONAVLA
# 185646                 LNL                             LONAVLA
# 185647                 LNL                             LONAVLA
# 185648                 LNL                             LONAVLA
# 185649                 LNL                             LONAVLA
# 186029                PUNE                            PUNE JN.
# 186030                PUNE                            PUNE JN.
# 186031                PUNE                            PUNE JN.
# 186032                PUNE                            PUNE JN.
# 186033                PUNE                            PUNE JN.
#
# [4591 rows x 12 columns]
